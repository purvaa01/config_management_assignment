# %%
"""Ansible Assignment"""

# %%
"""
Q1. Install and configure Ansible, Puppet, or Chef on a local or cloud
environment. Write and execute basic configuration scripts.?
"""

# %% [markdown]
# ![Screenshot 2026-04-14 202405.png](data:image/png;base64,...)![Screenshot 2026-04-14 202422.png](data:image/png;base64,...)![Screenshot 2026-04-14 200858.png](data:image/png;base64,...)![Screenshot 2026-04-14 201830.png](data:image/png;base64,...)![Screenshot 2026-04-14 195936.png](data:image/png;base64,...)
